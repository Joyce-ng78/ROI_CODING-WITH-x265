# %% [markdown]
# # 1. Xử lý time encoder và decoder

# %%
import os
import re
import pandas as pd

# --- CẤU HÌNH ---
ROOT_DIR = 'logs_RCF'
OUTPUT_FILE = os.path.join(ROOT_DIR, 'Overall_time.xlsx')

# 1. Regex Encode: "encoded 100 frames in 4.16s"
REGEX_ENCODE = r"encoded \d+ frames in ([\d.]+)s"

# 2. Regex Decode: "Total Time:        4.347 sec."
# \s+ nghĩa là khớp với một hoặc nhiều khoảng trắng liên tiếp
REGEX_DECODE = r"Total Time:\s+([\d.]+)\s+sec"

# --- THỨ TỰ SẮP XẾP MONG MUỐN ---
CUSTOM_ORDER = [
    "motion",
    "nonroi_CQP",
    "nonroi_CRF",
    "saliency",
    # "yolov11",
    # "yolov11_fullresol",
    # "yolov11_old",
    # "yolov11_openvino",
    # "yolov11_openvino_fullresol",
    # "yolov5",
    # "yolov5_fullresol",
    # "yolov5_old",
    # "yolov5_openvino",
    # "yolov5_openvino_fullresol",
    # "yolov8",
    # "yolov8_fullresol",
    # "yolov8_old",
    # "yolov8_openvino",
    # "yolov8_openvino_fullresol",
    # "yolov9",
    # "yolov9_fullresol",
    # "yolov9_old",
    # "yolov9_openvino",
    # "yolov9_openvino_fullresol"
]

def generate_excel_report():
    print(f"--> Đang quét dữ liệu trong thư mục: {ROOT_DIR}...")
    
    records = []

    # --- 1. QUÉT FILE ---
    for root, dirs, files in os.walk(ROOT_DIR):
        for filename in files:
            if filename.endswith(".txt"):
                file_path = os.path.join(root, filename)
                try:
                    path_parts = os.path.normpath(file_path).split(os.sep)
                    if len(path_parts) < 3: continue
                    
                    qp_name = path_parts[-2]
                    method_name = path_parts[-3]
                    
                    if method_name == ROOT_DIR: continue
                except Exception:
                    continue

                with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                    content = f.read()
                    
                    # Lấy Encode Time
                    match_enc = re.search(REGEX_ENCODE, content)
                    enc_time = float(match_enc.group(1)) if match_enc else None
                    
                    # Lấy Decode Time
                    match_dec = re.search(REGEX_DECODE, content)
                    dec_time = float(match_dec.group(1)) if match_dec else None

                    # Chỉ lưu nếu lấy được ít nhất 1 trong 2 thông số
                    if enc_time is not None or dec_time is not None:
                        records.append({
                            'Method': method_name,
                            'QP': qp_name,
                            'Encode_Time': enc_time * 10 if enc_time is not None else None,
                            'Decode_Time': dec_time * 10 if dec_time is not None else None
                        })

    if not records:
        print("Không tìm thấy dữ liệu nào!")
        return

    # --- 2. XỬ LÝ DATAFRAME ---
    df = pd.DataFrame(records)
    
    # Hàm phụ trợ để xử lý bảng (Encode riêng, Decode riêng)
    def create_pivot(value_column):
        # Tính trung bình
        df_avg = df.groupby(['Method', 'QP'])[value_column].mean().reset_index()
        # Xoay bảng
        pivot = df_avg.pivot(index='Method', columns='QP', values=value_column)
        
        # Sắp xếp hàng (Method) theo Custom Order
        available = [m for m in CUSTOM_ORDER if m in pivot.index]
        others = [m for m in pivot.index if m not in CUSTOM_ORDER]
        pivot = pivot.reindex(available + others)
        
        # Sắp xếp cột (QP) theo số
        try:
            sorted_cols = sorted(pivot.columns, key=lambda x: int(re.search(r'\d+', x).group()) if re.search(r'\d+', x) else 0)
            pivot = pivot[sorted_cols]
        except:
            pass
            
        # --- CẬP NHẬT MỚI: TÍNH AVERAGE ---
        # axis=1 nghĩa là tính trung bình theo hàng ngang (qua các cột QP)
        pivot['Average'] = pivot.mean(axis=1)
            
        return pivot

    # Tạo 2 bảng riêng biệt
    df_encode_final = create_pivot('Encode_Time')
    df_decode_final = create_pivot('Decode_Time')

    # --- 3. XUẤT RA EXCEL (2 SHEETS) ---
    print(f"--> Đang lưu file Excel tại: {OUTPUT_FILE}")
    
    with pd.ExcelWriter(OUTPUT_FILE, engine='openpyxl') as writer:
        df_encode_final.to_excel(writer, sheet_name='Encode Time (s)')
        df_decode_final.to_excel(writer, sheet_name='Decode Time (s)')
        
    print("--> Hoàn tất! File có 2 tab: 'Encode Time' và 'Decode Time'.")

if __name__ == "__main__":
    generate_excel_report()
# Out:
# --> Đang quét dữ liệu trong thư mục: logs_RCF...
# --> Đang lưu file Excel tại: logs_RCF/Overall_time.xlsx
# --> Hoàn tất! File có 2 tab: 'Encode Time' và 'Decode Time'.

# %% [markdown]
# # 2. Extract roi time

# %% [markdown]
# # 3. TÍNH TOÁN PSNR và BPP
# tôi có các file gốc yuv là
# ```
# input_yuv/
#     class_B/
#         Cactus_1920x1080_100.yuv
#         ....
# ```
# và các file yuv đã compress lần lượt nằm trong
# ```output_RCF/
#     motion/
#         qp42/
#             BasketballDrive_1920x1080_100.yuv
#             ...
#         qp47/
#             ...
#         ...
#     yolov9/
#         ...
# ```

# %%
import os
import re
import math
import numpy as np
import pandas as pd

# --- CẤU HÌNH ---
INPUT_DIR = 'input_yuv'          # Thư mục chứa video gốc
OUTPUT_DIR = 'output_RCF'        # Thư mục chứa video đã nén/reconstruct
RESULT_FILE = 'report_psnr_bpp.xlsx'

# Đuôi file bitstream để tính BPP (nếu file nén của bạn là .h265 hay .bit thì sửa ở đây)
COMPRESSED_EXT = '.bin' 

# Regex để lấy thông tin từ tên file: Name_WxH_Frames.yuv
# Ví dụ: Cactus_1920x1080_100.yuv
REGEX_FILENAME = r"(.+)_(\d+)x(\d+)_(\d+)"

# --- THỨ TỰ SẮP XẾP METHOD (như yêu cầu cũ) ---
CUSTOM_ORDER = [
    "motion",
    "nonroi_CQP",
    "nonroi_CRF",
    "saliency",
    "yolov11",
    "yolov11_fullresol",
    "yolov11_old",
    "yolov11_openvino",
    "yolov11_openvino_fullresol",
    "yolov5",
    "yolov5_fullresol",
    "yolov5_old",
    "yolov5_openvino",
    "yolov5_openvino_fullresol",
    "yolov8",
    "yolov8_fullresol",
    "yolov8_old",
    "yolov8_openvino",
    "yolov8_openvino_fullresol",
    "yolov9",
    "yolov9_fullresol",
    "yolov9_old",
    "yolov9_openvino",
    "yolov9_openvino_fullresol"
]

def parse_filename(filename):
    """Lấy Resolution và Frame count từ tên file"""
    match = re.search(REGEX_FILENAME, filename)
    if match:
        name = match.group(1)
        width = int(match.group(2))
        height = int(match.group(3))
        frames = int(match.group(4))
        return name, width, height, frames
    return None, 0, 0, 0

def calculate_y_psnr(raw_path, rec_path, width, height, frames):
    """Tính PSNR (chỉ kênh Y - Luma) giữa 2 file YUV"""
    # YUV420p: Frame size = W*H + W/2*H/2 * 2 = W*H * 1.5
    # Kênh Y chiếm W*H byte đầu tiên của mỗi frame
    y_size = width * height
    uv_size = (width // 2) * (height // 2) * 2
    frame_size = y_size + uv_size
    
    psnr_list = []
    
    try:
        with open(raw_path, 'rb') as f_raw, open(rec_path, 'rb') as f_rec:
            for _ in range(frames):
                # Đọc kênh Y
                raw_data = f_raw.read(y_size)
                rec_data = f_rec.read(y_size)
                
                # Nếu hết file sớm
                if not raw_data or not rec_data: 
                    break
                
                # Chuyển sang numpy array để tính toán nhanh
                raw_y = np.frombuffer(raw_data, dtype=np.uint8).astype(np.float64)
                rec_y = np.frombuffer(rec_data, dtype=np.uint8).astype(np.float64)
                
                mse = np.mean((raw_y - rec_y) ** 2)
                
                if mse == 0:
                    psnr_list.append(100.0) # Ảnh giống hệt nhau
                else:
                    psnr = 10.0 * math.log10((255.0 ** 2) / mse)
                    psnr_list.append(psnr)
                
                # Bỏ qua phần UV để nhảy sang frame tiếp theo
                f_raw.seek(uv_size, 1)
                f_rec.seek(uv_size, 1)
                
    except Exception as e:
        print(f"Lỗi khi đọc file {os.path.basename(raw_path)}: {e}")
        return None

    if not psnr_list:
        return None
        
    return np.mean(psnr_list)

def calculate_bpp(bin_path, width, height, frames):
    """Tính Bits Per Pixel từ file bitstream"""
    if not os.path.exists(bin_path):
        return None
        
    file_size_bytes = os.path.getsize(bin_path)
    total_bits = file_size_bytes * 8
    total_pixels = width * height * frames
    
    if total_pixels == 0: return 0
    return total_bits / total_pixels

def scan_files():
    # 1. Map file gốc: Tạo từ điển { 'TenFile_Goc': 'Duong_Dan_Full' }
    print("--> Đang quét thư mục Input...")
    raw_files_map = {}
    for root, dirs, files in os.walk(INPUT_DIR):
        for f in files:
            if f.endswith('.yuv'):
                # Key là tên file (ví dụ: Cactus_1920x1080_100.yuv)
                raw_files_map[f] = os.path.join(root, f)

    records = []
    print(f"--> Đang xử lý thư mục Output (tính PSNR & BPP)...")
    
    for root, dirs, files in os.walk(OUTPUT_DIR):
        for filename in files:
            if filename.endswith(".yuv"):
                # Cấu trúc output_RCF/Method/QP/File.yuv
                path_parts = os.path.normpath(os.path.join(root, filename)).split(os.sep)
                if len(path_parts) < 3: continue

                qp_name = path_parts[-2]      # vd: qp42
                method_name = path_parts[-3]  # vd: motion
                
                if method_name == OUTPUT_DIR: continue # Bỏ qua root

                # Tìm file gốc tương ứng
                if filename not in raw_files_map:
                    print(f"[Warn] Không tìm thấy file gốc cho: {filename}")
                    continue
                
                raw_path = raw_files_map[filename]
                rec_path = os.path.join(root, filename)
                
                # Parse thông số
                name_core, w, h, frames = parse_filename(filename)
                if w == 0 or h == 0: continue

                # --- TÍNH PSNR ---
                avg_psnr = calculate_y_psnr(raw_path, rec_path, w, h, frames)
                
                # --- TÍNH BPP ---
                # Giả định file bitstream (.bin) nằm cùng chỗ với file rec (.yuv)
                # Tên file bitstream thường giống file yuv nhưng khác đuôi
                bin_filename = filename.replace('.yuv', COMPRESSED_EXT)
                bin_path = os.path.join(root, bin_filename)
                
                bpp_val = calculate_bpp(bin_path, w, h, frames)
                
                if avg_psnr is not None:
                    print(f"[{method_name} - {qp_name}] {filename}: PSNR={avg_psnr:.2f}, BPP={bpp_val if bpp_val else 'N/A'}")
                    records.append({
                        'Method': method_name,
                        'QP': qp_name,
                        'PSNR': avg_psnr,
                        'BPP': bpp_val
                    })

    return pd.DataFrame(records)

def create_pivot(df, value_col):
    """Hàm tạo bảng Pivot và tính cột Average"""
    if df.empty: return pd.DataFrame()
    
    # Pivot
    pivot = df.pivot_table(index='Method', columns='QP', values=value_col, aggfunc='mean')
    
    # Sắp xếp Method
    available = [m for m in CUSTOM_ORDER if m in pivot.index]
    others = [m for m in pivot.index if m not in CUSTOM_ORDER]
    pivot = pivot.reindex(available + others)
    
    # Sắp xếp QP cột
    try:
        sorted_cols = sorted(pivot.columns, key=lambda x: int(re.search(r'\d+', x).group()) if re.search(r'\d+', x) else 0)
        pivot = pivot[sorted_cols]
    except:
        pass
        
    # Tính Average theo hàng (trung bình các QP)
    pivot['Average'] = pivot.mean(axis=1)
    
    return pivot

def main():
    df = scan_files()
    
    if df.empty:
        print("Không có dữ liệu để xuất file.")
        return

    print(f"--> Đang xuất Excel: {RESULT_FILE}")
    
    # Tạo 2 bảng
    df_psnr = create_pivot(df, 'PSNR')
    df_bpp = create_pivot(df, 'BPP')
    
    with pd.ExcelWriter(RESULT_FILE, engine='openpyxl') as writer:
        df_psnr.to_excel(writer, sheet_name='Average PSNR (dB)')
        df_bpp.to_excel(writer, sheet_name='Average BPP')
        
    print("--> Hoàn tất!")

if __name__ == "__main__":
    main()
# Out:
# --> Đang quét thư mục Input...
# --> Đang xử lý thư mục Output (tính PSNR & BPP)...
# [yolov8 - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.38, BPP=0.006162075617283951
# [yolov8 - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.30, BPP=0.001887577160493827
# [yolov8 - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.53, BPP=0.00242662037037037
# [yolov8 - qp47] Kimono_1920x1080_100.yuv: PSNR=28.64, BPP=0.0035142746913580246
# [yolov8 - qp47] Cactus_1920x1080_100.yuv: PSNR=26.47, BPP=0.0038683256172839507
# [yolov8 - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.78, BPP=0.012004320987654322
# [yolov8 - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.80, BPP=0.0032968364197530865
# [yolov8 - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.41, BPP=0.004983989197530864
# [yolov8 - qp42] Kimono_1920x1080_100.yuv: PSNR=31.00, BPP=0.007100424382716049
# [yolov8 - qp42] Cactus_1920x1080_100.yuv: PSNR=28.61, BPP=0.007674884259259259
# [yolov8 - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.43, BPP=0.04348707561728395
# [yolov8 - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.55, BPP=0.020310262345679012
# [yolov8 - qp32] ParkScene_1920x1080_100.yuv: PSNR=33.00, BPP=0.024777006172839507
# [yolov8 - qp32] Kimono_1920x1080_100.yuv: PSNR=36.38, BPP=0.029662345679012346
# [yolov8 - qp32] Cactus_1920x1080_100.yuv: PSNR=33.53, BPP=0.032469521604938274
# [yolov8 - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.25, BPP=0.08725671296296296
# [yolov8 - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.48, BPP=0.0626323688271605
# [yolov8 - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.51, BPP=0.055554320987654324
# [yolov8 - qp27] Kimono_1920x1080_100.yuv: PSNR=38.85, BPP=0.05803148148148148
# [yolov8 - qp27] Cactus_1920x1080_100.yuv: PSNR=35.75, BPP=0.06981547067901235
# [yolov8 - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.88, BPP=0.21317299382716048
# [yolov8 - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.23, BPP=0.1964309413580247
# [yolov8 - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.01, BPP=0.12559841820987655
# [yolov8 - qp22] Kimono_1920x1080_100.yuv: PSNR=40.84, BPP=0.11513915895061728
# [yolov8 - qp22] Cactus_1920x1080_100.yuv: PSNR=37.54, BPP=0.1780306712962963
# [yolov8 - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.24, BPP=0.022874498456790123
# [yolov8 - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.37, BPP=0.007443557098765432
# [yolov8 - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.61, BPP=0.011027391975308642
# [yolov8 - qp37] Kimono_1920x1080_100.yuv: PSNR=33.67, BPP=0.014751581790123456
# [yolov8 - qp37] Cactus_1920x1080_100.yuv: PSNR=31.07, BPP=0.015780748456790124
# [yolov8_fullresol - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.39, BPP=0.006098225308641975
# [yolov8_fullresol - qp47] BQTerrace_1920x1080_100.yuv: PSNR=26.24, BPP=0.002358024691358025
# [yolov8_fullresol - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.26, BPP=0.0022305555555555555
# [yolov8_fullresol - qp47] Kimono_1920x1080_100.yuv: PSNR=28.61, BPP=0.0034252314814814814
# [yolov8_fullresol - qp47] Cactus_1920x1080_100.yuv: PSNR=26.42, BPP=0.0037783564814814815
# [yolov8_fullresol - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.78, BPP=0.01193869598765432
# [yolov8_fullresol - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.64, BPP=0.004142091049382716
# [yolov8_fullresol - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.10, BPP=0.0045285879629629626
# [yolov8_fullresol - qp42] Kimono_1920x1080_100.yuv: PSNR=30.93, BPP=0.006926658950617284
# [yolov8_fullresol - qp42] Cactus_1920x1080_100.yuv: PSNR=28.55, BPP=0.007341743827160494
# [yolov8_fullresol - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.44, BPP=0.04332515432098766
# [yolov8_fullresol - qp32] BQTerrace_1920x1080_100.yuv: PSNR=33.14, BPP=0.03014224537037037
# [yolov8_fullresol - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.67, BPP=0.02265181327160494
# [yolov8_fullresol - qp32] Kimono_1920x1080_100.yuv: PSNR=36.32, BPP=0.029071450617283952
# [yolov8_fullresol - qp32] Cactus_1920x1080_100.yuv: PSNR=33.42, BPP=0.03054513888888889
# [yolov8_fullresol - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.26, BPP=0.08705929783950617
# [yolov8_fullresol - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.90, BPP=0.09296766975308642
# [yolov8_fullresol - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.21, BPP=0.05111801697530864
# [yolov8_fullresol - qp27] Kimono_1920x1080_100.yuv: PSNR=38.80, BPP=0.056822878086419754
# [yolov8_fullresol - qp27] Cactus_1920x1080_100.yuv: PSNR=35.59, BPP=0.06536226851851852
# [yolov8_fullresol - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.90, BPP=0.21411547067901235
# [yolov8_fullresol - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.84, BPP=0.2993076774691358
# [yolov8_fullresol - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.77, BPP=0.11561030092592593
# [yolov8_fullresol - qp22] Kimono_1920x1080_100.yuv: PSNR=40.80, BPP=0.11208969907407407
# [yolov8_fullresol - qp22] Cactus_1920x1080_100.yuv: PSNR=37.43, BPP=0.16960146604938273
# [yolov8_fullresol - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.23, BPP=0.022801041666666667
# [yolov8_fullresol - qp37] BQTerrace_1920x1080_100.yuv: PSNR=31.05, BPP=0.009827970679012346
# [yolov8_fullresol - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.26, BPP=0.010044135802469135
# [yolov8_fullresol - qp37] Kimono_1920x1080_100.yuv: PSNR=33.61, BPP=0.01444903549382716
# [yolov8_fullresol - qp37] Cactus_1920x1080_100.yuv: PSNR=30.98, BPP=0.014915817901234567
# [yolov9 - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.34, BPP=0.0061645833333333335
# [yolov9 - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.38, BPP=0.0019130401234567901
# [yolov9 - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.69, BPP=0.0026683256172839506
# [yolov9 - qp47] Kimono_1920x1080_100.yuv: PSNR=28.63, BPP=0.003489043209876543
# [yolov9 - qp47] Cactus_1920x1080_100.yuv: PSNR=27.01, BPP=0.004186998456790124
# [yolov9 - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.72, BPP=0.012009567901234568
# [yolov9 - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.88, BPP=0.0033415123456790124
# [yolov9 - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.58, BPP=0.005483873456790123
# [yolov9 - qp42] Kimono_1920x1080_100.yuv: PSNR=30.96, BPP=0.007084606481481482
# [yolov9 - qp42] Cactus_1920x1080_100.yuv: PSNR=29.26, BPP=0.008242708333333333
# [yolov9 - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.40, BPP=0.043431712962962964
# [yolov9 - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.54, BPP=0.019983796296296295
# [yolov9 - qp32] ParkScene_1920x1080_100.yuv: PSNR=33.13, BPP=0.026926466049382716
# [yolov9 - qp32] Kimono_1920x1080_100.yuv: PSNR=36.37, BPP=0.02956886574074074
# [yolov9 - qp32] Cactus_1920x1080_100.yuv: PSNR=34.08, BPP=0.034244135802469135
# [yolov9 - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.23, BPP=0.08698908179012346
# [yolov9 - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.47, BPP=0.06112816358024691
# [yolov9 - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.61, BPP=0.059998996913580245
# [yolov9 - qp27] Kimono_1920x1080_100.yuv: PSNR=38.84, BPP=0.057775
# [yolov9 - qp27] Cactus_1920x1080_100.yuv: PSNR=36.15, BPP=0.07499868827160494
# [yolov9 - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.87, BPP=0.21238337191358025
# [yolov9 - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.19, BPP=0.18934313271604938
# [yolov9 - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.09, BPP=0.13414247685185185
# [yolov9 - qp22] Kimono_1920x1080_100.yuv: PSNR=40.83, BPP=0.11464776234567901
# [yolov9 - qp22] Cactus_1920x1080_100.yuv: PSNR=37.81, BPP=0.19728915895061727
# [yolov9 - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.19, BPP=0.022844907407407408
# [yolov9 - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.38, BPP=0.007324151234567902
# [yolov9 - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.75, BPP=0.012109837962962963
# [yolov9 - qp37] Kimono_1920x1080_100.yuv: PSNR=33.65, BPP=0.014691126543209877
# [yolov9 - qp37] Cactus_1920x1080_100.yuv: PSNR=31.70, BPP=0.01676400462962963
# [yolov5_fullresol - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.35, BPP=0.006084220679012346
# [yolov5_fullresol - qp47] BQTerrace_1920x1080_100.yuv: PSNR=26.14, BPP=0.002289429012345679
# [yolov5_fullresol - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.36, BPP=0.0023707175925925927
# [yolov5_fullresol - qp47] Kimono_1920x1080_100.yuv: PSNR=28.54, BPP=0.003320563271604938
# [yolov5_fullresol - qp47] Cactus_1920x1080_100.yuv: PSNR=26.64, BPP=0.003995177469135802
# [yolov5_fullresol - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.74, BPP=0.01195625
# [yolov5_fullresol - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.67, BPP=0.004141820987654321
# [yolov5_fullresol - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.27, BPP=0.004918557098765432
# [yolov5_fullresol - qp42] Kimono_1920x1080_100.yuv: PSNR=30.83, BPP=0.006703973765432099
# [yolov5_fullresol - qp42] Cactus_1920x1080_100.yuv: PSNR=28.91, BPP=0.008076697530864197
# [yolov5_fullresol - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.40, BPP=0.043318171296296296
# [yolov5_fullresol - qp32] BQTerrace_1920x1080_100.yuv: PSNR=33.04, BPP=0.028050462962962965
# [yolov5_fullresol - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.81, BPP=0.024270524691358025
# [yolov5_fullresol - qp32] Kimono_1920x1080_100.yuv: PSNR=36.24, BPP=0.02820065586419753
# [yolov5_fullresol - qp32] Cactus_1920x1080_100.yuv: PSNR=33.78, BPP=0.0335266975308642
# [yolov5_fullresol - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.23, BPP=0.08697079475308642
# [yolov5_fullresol - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.79, BPP=0.08493792438271605
# [yolov5_fullresol - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.34, BPP=0.05434039351851852
# [yolov5_fullresol - qp27] Kimono_1920x1080_100.yuv: PSNR=38.73, BPP=0.05516566358024692
# [yolov5_fullresol - qp27] Cactus_1920x1080_100.yuv: PSNR=35.93, BPP=0.07219409722222223
# [yolov5_fullresol - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.87, BPP=0.2120445601851852
# [yolov5_fullresol - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.65, BPP=0.26761118827160496
# [yolov5_fullresol - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.86, BPP=0.12196697530864198
# [yolov5_fullresol - qp22] Kimono_1920x1080_100.yuv: PSNR=40.74, BPP=0.10858329475308642
# [yolov5_fullresol - qp22] Cactus_1920x1080_100.yuv: PSNR=37.67, BPP=0.18617677469135802
# [yolov5_fullresol - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.22, BPP=0.02281118827160494
# [yolov5_fullresol - qp37] BQTerrace_1920x1080_100.yuv: PSNR=31.03, BPP=0.009578279320987655
# [yolov5_fullresol - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.41, BPP=0.010850694444444444
# [yolov5_fullresol - qp37] Kimono_1920x1080_100.yuv: PSNR=33.51, BPP=0.013968518518518519
# [yolov5_fullresol - qp37] Cactus_1920x1080_100.yuv: PSNR=31.37, BPP=0.016333912037037036
# [saliency - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=27.30, BPP=0.0041916666666666665
# [saliency - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.00, BPP=0.0016643132716049384
# [saliency - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.50, BPP=0.0022712962962962964
# [saliency - qp47] Kimono_1920x1080_100.yuv: PSNR=28.57, BPP=0.0029942515432098767
# [saliency - qp47] Cactus_1920x1080_100.yuv: PSNR=26.28, BPP=0.0032042824074074074
# [saliency - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=29.50, BPP=0.006532484567901235
# [saliency - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.48, BPP=0.0028477623456790125
# [saliency - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.36, BPP=0.004585146604938271
# [saliency - qp42] Kimono_1920x1080_100.yuv: PSNR=31.01, BPP=0.0060906635802469135
# [saliency - qp42] Cactus_1920x1080_100.yuv: PSNR=28.37, BPP=0.006046913580246914
# [saliency - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=34.34, BPP=0.024587345679012346
# [saliency - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.27, BPP=0.015695331790123456
# [saliency - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.94, BPP=0.023732291666666665
# [saliency - qp32] Kimono_1920x1080_100.yuv: PSNR=36.44, BPP=0.02622662037037037
# [saliency - qp32] Cactus_1920x1080_100.yuv: PSNR=33.27, BPP=0.025040393518518517
# [saliency - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=36.34, BPP=0.047484490740740744
# [saliency - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.28, BPP=0.04846898148148148
# [saliency - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.45, BPP=0.05341871141975309
# [saliency - qp27] Kimono_1920x1080_100.yuv: PSNR=38.86, BPP=0.05125574845679012
# [saliency - qp27] Cactus_1920x1080_100.yuv: PSNR=35.50, BPP=0.05294409722222222
# [saliency - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=37.94, BPP=0.09716184413580246
# [saliency - qp22] BQTerrace_1920x1080_100.yuv: PSNR=35.97, BPP=0.14970050154320988
# [saliency - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.95, BPP=0.12044471450617283
# [saliency - qp22] Kimono_1920x1080_100.yuv: PSNR=40.80, BPP=0.09853881172839506
# [saliency - qp22] Cactus_1920x1080_100.yuv: PSNR=37.30, BPP=0.1312869212962963
# [saliency - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=32.02, BPP=0.012852816358024691
# [saliency - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.05, BPP=0.006015702160493827
# [saliency - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.55, BPP=0.010408179012345678
# [saliency - qp37] Kimono_1920x1080_100.yuv: PSNR=33.73, BPP=0.012938541666666666
# [saliency - qp37] Cactus_1920x1080_100.yuv: PSNR=30.80, BPP=0.012313233024691358
# [yolov11_old - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.35, BPP=0.00614471450617284
# [yolov11_old - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.61, BPP=0.0020464891975308644
# [yolov11_old - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.57, BPP=0.002443942901234568
# [yolov11_old - qp47] Kimono_1920x1080_100.yuv: PSNR=28.58, BPP=0.003444212962962963
# [yolov11_old - qp47] Cactus_1920x1080_100.yuv: PSNR=26.20, BPP=0.0031471064814814816
# [yolov11_old - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.74, BPP=0.011934104938271605
# [yolov11_old - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.18, BPP=0.0036784722222222223
# [yolov11_old - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.45, BPP=0.005046566358024691
# [yolov11_old - qp42] Kimono_1920x1080_100.yuv: PSNR=30.91, BPP=0.006939853395061728
# [yolov11_old - qp42] Cactus_1920x1080_100.yuv: PSNR=28.27, BPP=0.005825925925925926
# [yolov11_old - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.38, BPP=0.04321057098765432
# [yolov11_old - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.76, BPP=0.022695023148148148
# [yolov11_old - qp32] ParkScene_1920x1080_100.yuv: PSNR=33.04, BPP=0.025069058641975308
# [yolov11_old - qp32] Kimono_1920x1080_100.yuv: PSNR=36.32, BPP=0.028966435185185185
# [yolov11_old - qp32] Cactus_1920x1080_100.yuv: PSNR=33.07, BPP=0.02401466049382716
# [yolov11_old - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.21, BPP=0.08651678240740741
# [yolov11_old - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.61, BPP=0.06919749228395061
# [yolov11_old - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.55, BPP=0.05623931327160494
# [yolov11_old - qp27] Kimono_1920x1080_100.yuv: PSNR=38.80, BPP=0.05679128086419753
# [yolov11_old - qp27] Cactus_1920x1080_100.yuv: PSNR=35.29, BPP=0.05239135802469136
# [yolov11_old - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.86, BPP=0.21087283950617283
# [yolov11_old - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.37, BPP=0.2191505787037037
# [yolov11_old - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.05, BPP=0.12711350308641975
# [yolov11_old - qp22] Kimono_1920x1080_100.yuv: PSNR=40.80, BPP=0.11259378858024692
# [yolov11_old - qp22] Cactus_1920x1080_100.yuv: PSNR=37.18, BPP=0.1406872299382716
# [yolov11_old - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.17, BPP=0.022754128086419752
# [yolov11_old - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.68, BPP=0.008301697530864198
# [yolov11_old - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.64, BPP=0.011127006172839507
# [yolov11_old - qp37] Kimono_1920x1080_100.yuv: PSNR=33.60, BPP=0.014414737654320988
# [yolov11_old - qp37] Cactus_1920x1080_100.yuv: PSNR=30.63, BPP=0.011841859567901234
# [yolov5_openvino - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.35, BPP=0.006084722222222222
# [yolov5_openvino - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.32, BPP=0.001906520061728395
# [yolov5_openvino - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.42, BPP=0.002311882716049383
# [yolov5_openvino - qp47] Kimono_1920x1080_100.yuv: PSNR=28.60, BPP=0.003462114197530864
# [yolov5_openvino - qp47] Cactus_1920x1080_100.yuv: PSNR=26.62, BPP=0.003868094135802469
# [yolov5_openvino - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.76, BPP=0.01192974537037037
# [yolov5_openvino - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.95, BPP=0.003386149691358025
# [yolov5_openvino - qp42] ParkScene_1920x1080_100.yuv: PSNR=29.16, BPP=0.004863541666666667
# [yolov5_openvino - qp42] Kimono_1920x1080_100.yuv: PSNR=30.96, BPP=0.007019521604938271
# [yolov5_openvino - qp42] Cactus_1920x1080_100.yuv: PSNR=28.80, BPP=0.007755208333333334
# [yolov5_openvino - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.40, BPP=0.04336319444444445
# [yolov5_openvino - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.57, BPP=0.019974382716049382
# [yolov5_openvino - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.93, BPP=0.02427619598765432
# [yolov5_openvino - qp32] Kimono_1920x1080_100.yuv: PSNR=36.34, BPP=0.029378742283950616
# [yolov5_openvino - qp32] Cactus_1920x1080_100.yuv: PSNR=33.81, BPP=0.033262152777777776
# [yolov5_openvino - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.23, BPP=0.08687087191358024
# [yolov5_openvino - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.48, BPP=0.06091118827160494
# [yolov5_openvino - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.46, BPP=0.05494610339506173
# [yolov5_openvino - qp27] Kimono_1920x1080_100.yuv: PSNR=38.82, BPP=0.057449266975308645
# [yolov5_openvino - qp27] Cactus_1920x1080_100.yuv: PSNR=35.99, BPP=0.07192337962962964
# [yolov5_openvino - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.87, BPP=0.2120557098765432
# [yolov5_openvino - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.20, BPP=0.18961917438271605
# [yolov5_openvino - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.98, BPP=0.12405081018518518
# [yolov5_openvino - qp22] Kimono_1920x1080_100.yuv: PSNR=40.81, BPP=0.11379282407407408
# [yolov5_openvino - qp22] Cactus_1920x1080_100.yuv: PSNR=37.72, BPP=0.18673950617283952
# [yolov5_openvino - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.21, BPP=0.02279826388888889
# [yolov5_openvino - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.40, BPP=0.0073347608024691355
# [yolov5_openvino - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.52, BPP=0.010797800925925926
# [yolov5_openvino - qp37] Kimono_1920x1080_100.yuv: PSNR=33.63, BPP=0.014634683641975309
# [yolov5_openvino - qp37] Cactus_1920x1080_100.yuv: PSNR=31.38, BPP=0.016247685185185184
# [yolov5_old - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.33, BPP=0.006173263888888889
# [yolov5_old - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.47, BPP=0.0019617669753086418
# [yolov5_old - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.47, BPP=0.002355324074074074
# [yolov5_old - qp47] Kimono_1920x1080_100.yuv: PSNR=28.63, BPP=0.0034837577160493826
# [yolov5_old - qp47] Cactus_1920x1080_100.yuv: PSNR=26.68, BPP=0.004015663580246914
# [yolov5_old - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.76, BPP=0.01196087962962963
# [yolov5_old - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.92, BPP=0.003375462962962963
# [yolov5_old - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.33, BPP=0.004865007716049382
# [yolov5_old - qp42] Kimono_1920x1080_100.yuv: PSNR=30.96, BPP=0.007063503086419753
# [yolov5_old - qp42] Cactus_1920x1080_100.yuv: PSNR=28.87, BPP=0.007915239197530864
# [yolov5_old - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.40, BPP=0.04331219135802469
# [yolov5_old - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.56, BPP=0.020048032407407407
# [yolov5_old - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.93, BPP=0.024290470679012344
# [yolov5_old - qp32] Kimono_1920x1080_100.yuv: PSNR=36.35, BPP=0.029374112654320987
# [yolov5_old - qp32] Cactus_1920x1080_100.yuv: PSNR=33.83, BPP=0.033337075617283954
# [yolov5_old - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.23, BPP=0.08683576388888889
# [yolov5_old - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.48, BPP=0.06094266975308642
# [yolov5_old - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.46, BPP=0.05494054783950617
# [yolov5_old - qp27] Kimono_1920x1080_100.yuv: PSNR=38.83, BPP=0.057483989197530866
# [yolov5_old - qp27] Cactus_1920x1080_100.yuv: PSNR=36.01, BPP=0.07219710648148148
# [yolov5_old - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.87, BPP=0.2120917052469136
# [yolov5_old - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.20, BPP=0.19018506944444444
# [yolov5_old - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.97, BPP=0.12403302469135802
# [yolov5_old - qp22] Kimono_1920x1080_100.yuv: PSNR=40.81, BPP=0.11377488425925926
# [yolov5_old - qp22] Cactus_1920x1080_100.yuv: PSNR=37.72, BPP=0.1871488425925926
# [yolov5_old - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.19, BPP=0.022823186728395062
# [yolov5_old - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.40, BPP=0.007363734567901235
# [yolov5_old - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.52, BPP=0.010803163580246914
# [yolov5_old - qp37] Kimono_1920x1080_100.yuv: PSNR=33.63, BPP=0.014619598765432099
# [yolov5_old - qp37] Cactus_1920x1080_100.yuv: PSNR=31.37, BPP=0.016192708333333333
# [yolov9_fullresol - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.33, BPP=0.006111072530864198
# [yolov9_fullresol - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.71, BPP=0.0021311728395061727
# [yolov9_fullresol - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.55, BPP=0.0025924382716049385
# [yolov9_fullresol - qp47] Kimono_1920x1080_100.yuv: PSNR=28.61, BPP=0.003448804012345679
# [yolov9_fullresol - qp47] Cactus_1920x1080_100.yuv: PSNR=26.72, BPP=0.003682368827160494
# [yolov9_fullresol - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.71, BPP=0.011882098765432099
# [yolov9_fullresol - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.15, BPP=0.0036881944444444445
# [yolov9_fullresol - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.42, BPP=0.005335185185185185
# [yolov9_fullresol - qp42] Kimono_1920x1080_100.yuv: PSNR=30.96, BPP=0.006995486111111111
# [yolov9_fullresol - qp42] Cactus_1920x1080_100.yuv: PSNR=28.98, BPP=0.007160802469135802
# [yolov9_fullresol - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.38, BPP=0.0430934799382716
# [yolov9_fullresol - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.78, BPP=0.024362577160493826
# [yolov9_fullresol - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.99, BPP=0.026593479938271606
# [yolov9_fullresol - qp32] Kimono_1920x1080_100.yuv: PSNR=36.35, BPP=0.029264583333333333
# [yolov9_fullresol - qp32] Cactus_1920x1080_100.yuv: PSNR=33.79, BPP=0.029745601851851853
# [yolov9_fullresol - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.22, BPP=0.08638152006172839
# [yolov9_fullresol - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.63, BPP=0.07460165895061728
# [yolov9_fullresol - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.52, BPP=0.05978993055555556
# [yolov9_fullresol - qp27] Kimono_1920x1080_100.yuv: PSNR=38.83, BPP=0.05736840277777778
# [yolov9_fullresol - qp27] Cactus_1920x1080_100.yuv: PSNR=35.90, BPP=0.06348344907407408
# [yolov9_fullresol - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.87, BPP=0.21153472222222222
# [yolov9_fullresol - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.44, BPP=0.2373849151234568
# [yolov9_fullresol - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.04, BPP=0.13519625771604937
# [yolov9_fullresol - qp22] Kimono_1920x1080_100.yuv: PSNR=40.82, BPP=0.11412878086419753
# [yolov9_fullresol - qp22] Cactus_1920x1080_100.yuv: PSNR=37.61, BPP=0.16532052469135802
# [yolov9_fullresol - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.17, BPP=0.02267943672839506
# [yolov9_fullresol - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.59, BPP=0.008428973765432099
# [yolov9_fullresol - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.58, BPP=0.011853356481481482
# [yolov9_fullresol - qp37] Kimono_1920x1080_100.yuv: PSNR=33.63, BPP=0.014558680555555556
# [yolov9_fullresol - qp37] Cactus_1920x1080_100.yuv: PSNR=31.41, BPP=0.014522299382716049
# [yolov8_openvino - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.34, BPP=0.006104128086419753
# [yolov8_openvino - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.15, BPP=0.0018159722222222223
# [yolov8_openvino - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.48, BPP=0.002367283950617284
# [yolov8_openvino - qp47] Kimono_1920x1080_100.yuv: PSNR=28.64, BPP=0.00349429012345679
# [yolov8_openvino - qp47] Cactus_1920x1080_100.yuv: PSNR=26.39, BPP=0.0037856481481481482
# [yolov8_openvino - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.74, BPP=0.011911728395061728
# [yolov8_openvino - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.66, BPP=0.0031938657407407406
# [yolov8_openvino - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.36, BPP=0.004863657407407408
# [yolov8_openvino - qp42] Kimono_1920x1080_100.yuv: PSNR=30.99, BPP=0.007075154320987654
# [yolov8_openvino - qp42] Cactus_1920x1080_100.yuv: PSNR=28.54, BPP=0.007507175925925926
# [yolov8_openvino - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.42, BPP=0.04323194444444445
# [yolov8_openvino - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.46, BPP=0.019101041666666665
# [yolov8_openvino - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.96, BPP=0.024308063271604938
# [yolov8_openvino - qp32] Kimono_1920x1080_100.yuv: PSNR=36.38, BPP=0.029618557098765434
# [yolov8_openvino - qp32] Cactus_1920x1080_100.yuv: PSNR=33.49, BPP=0.03191971450617284
# [yolov8_openvino - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.25, BPP=0.08681230709876543
# [yolov8_openvino - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.42, BPP=0.0591712962962963
# [yolov8_openvino - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.48, BPP=0.054728240740740744
# [yolov8_openvino - qp27] Kimono_1920x1080_100.yuv: PSNR=38.85, BPP=0.05794645061728395
# [yolov8_openvino - qp27] Cactus_1920x1080_100.yuv: PSNR=35.72, BPP=0.06867322530864198
# [yolov8_openvino - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.89, BPP=0.21283136574074074
# [yolov8_openvino - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.20, BPP=0.19060304783950618
# [yolov8_openvino - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.98, BPP=0.12411878858024691
# [yolov8_openvino - qp22] Kimono_1920x1080_100.yuv: PSNR=40.84, BPP=0.11535408950617283
# [yolov8_openvino - qp22] Cactus_1920x1080_100.yuv: PSNR=37.52, BPP=0.1756119212962963
# [yolov8_openvino - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.20, BPP=0.022726118827160493
# [yolov8_openvino - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.18, BPP=0.0070251543209876545
# [yolov8_openvino - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.53, BPP=0.010804012345679013
# [yolov8_openvino - qp37] Kimono_1920x1080_100.yuv: PSNR=33.66, BPP=0.014702237654320988
# [yolov8_openvino - qp37] Cactus_1920x1080_100.yuv: PSNR=31.01, BPP=0.015476041666666667
# [yolov9_openvino_fullresol - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.33, BPP=0.006098302469135802
# [yolov9_openvino_fullresol - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.71, BPP=0.002115702160493827
# [yolov9_openvino_fullresol - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.57, BPP=0.0025798996913580247
# [yolov9_openvino_fullresol - qp47] Kimono_1920x1080_100.yuv: PSNR=28.60, BPP=0.003447685185185185
# [yolov9_openvino_fullresol - qp47] Cactus_1920x1080_100.yuv: PSNR=26.73, BPP=0.0036765817901234566
# [yolov9_openvino_fullresol - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.71, BPP=0.011877507716049382
# [yolov9_openvino_fullresol - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.14, BPP=0.003715817901234568
# [yolov9_openvino_fullresol - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.41, BPP=0.005313850308641975
# [yolov9_openvino_fullresol - qp42] Kimono_1920x1080_100.yuv: PSNR=30.95, BPP=0.006995061728395062
# [yolov9_openvino_fullresol - qp42] Cactus_1920x1080_100.yuv: PSNR=28.97, BPP=0.0071673225308641975
# [yolov9_openvino_fullresol - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.38, BPP=0.04310694444444445
# [yolov9_openvino_fullresol - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.79, BPP=0.024431635802469136
# [yolov9_openvino_fullresol - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.99, BPP=0.026517939814814814
# [yolov9_openvino_fullresol - qp32] Kimono_1920x1080_100.yuv: PSNR=36.35, BPP=0.029276967592592594
# [yolov9_openvino_fullresol - qp32] Cactus_1920x1080_100.yuv: PSNR=33.79, BPP=0.029734529320987656
# [yolov9_openvino_fullresol - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.23, BPP=0.0863829475308642
# [yolov9_openvino_fullresol - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.63, BPP=0.07456871141975309
# [yolov9_openvino_fullresol - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.50, BPP=0.0595369212962963
# [yolov9_openvino_fullresol - qp27] Kimono_1920x1080_100.yuv: PSNR=38.83, BPP=0.05735219907407407
# [yolov9_openvino_fullresol - qp27] Cactus_1920x1080_100.yuv: PSNR=35.90, BPP=0.06357341820987654
# [yolov9_openvino_fullresol - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.87, BPP=0.2117993827160494
# [yolov9_openvino_fullresol - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.44, BPP=0.2372025462962963
# [yolov9_openvino_fullresol - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.02, BPP=0.13456820987654322
# [yolov9_openvino_fullresol - qp22] Kimono_1920x1080_100.yuv: PSNR=40.82, BPP=0.11409097222222223
# [yolov9_openvino_fullresol - qp22] Cactus_1920x1080_100.yuv: PSNR=37.61, BPP=0.16547341820987654
# [yolov9_openvino_fullresol - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.17, BPP=0.02267303240740741
# [yolov9_openvino_fullresol - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.59, BPP=0.008468016975308641
# [yolov9_openvino_fullresol - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.58, BPP=0.011821566358024692
# [yolov9_openvino_fullresol - qp37] Kimono_1920x1080_100.yuv: PSNR=33.63, BPP=0.014563966049382716
# [yolov9_openvino_fullresol - qp37] Cactus_1920x1080_100.yuv: PSNR=31.41, BPP=0.0145508487654321
# [yolov11_fullresol - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.38, BPP=0.006070679012345679
# [yolov11_fullresol - qp47] BQTerrace_1920x1080_100.yuv: PSNR=26.19, BPP=0.002262885802469136
# [yolov11_fullresol - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.45, BPP=0.0023283179012345678
# [yolov11_fullresol - qp47] Kimono_1920x1080_100.yuv: PSNR=28.50, BPP=0.0033225694444444444
# [yolov11_fullresol - qp47] Cactus_1920x1080_100.yuv: PSNR=26.79, BPP=0.0038697916666666668
# [yolov11_fullresol - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.72, BPP=0.011885416666666667
# [yolov11_fullresol - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.58, BPP=0.00400516975308642
# [yolov11_fullresol - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.31, BPP=0.004753202160493827
# [yolov11_fullresol - qp42] Kimono_1920x1080_100.yuv: PSNR=30.82, BPP=0.006662847222222222
# [yolov11_fullresol - qp42] Cactus_1920x1080_100.yuv: PSNR=29.06, BPP=0.007585223765432099
# [yolov11_fullresol - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.39, BPP=0.043194637345679014
# [yolov11_fullresol - qp32] BQTerrace_1920x1080_100.yuv: PSNR=33.10, BPP=0.028285609567901236
# [yolov11_fullresol - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.87, BPP=0.023697839506172838
# [yolov11_fullresol - qp32] Kimono_1920x1080_100.yuv: PSNR=36.22, BPP=0.02795408950617284
# [yolov11_fullresol - qp32] Cactus_1920x1080_100.yuv: PSNR=33.90, BPP=0.0317960262345679
# [yolov11_fullresol - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.24, BPP=0.08649282407407408
# [yolov11_fullresol - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.84, BPP=0.08660077160493827
# [yolov11_fullresol - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.39, BPP=0.05339976851851852
# [yolov11_fullresol - qp27] Kimono_1920x1080_100.yuv: PSNR=38.72, BPP=0.054845408950617285
# [yolov11_fullresol - qp27] Cactus_1920x1080_100.yuv: PSNR=36.00, BPP=0.0682704475308642
# [yolov11_fullresol - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.88, BPP=0.21248229166666666
# [yolov11_fullresol - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.72, BPP=0.27844591049382716
# [yolov11_fullresol - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.90, BPP=0.12072087191358025
# [yolov11_fullresol - qp22] Kimono_1920x1080_100.yuv: PSNR=40.73, BPP=0.10858896604938272
# [yolov11_fullresol - qp22] Cactus_1920x1080_100.yuv: PSNR=37.70, BPP=0.17868109567901236
# [yolov11_fullresol - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.20, BPP=0.02267793209876543
# [yolov11_fullresol - qp37] BQTerrace_1920x1080_100.yuv: PSNR=31.03, BPP=0.00960798611111111
# [yolov11_fullresol - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.47, BPP=0.010590933641975308
# [yolov11_fullresol - qp37] Kimono_1920x1080_100.yuv: PSNR=33.49, BPP=0.0138304012345679
# [yolov11_fullresol - qp37] Cactus_1920x1080_100.yuv: PSNR=31.50, BPP=0.015514699074074075
# [yolov5_openvino_fullresol - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.31, BPP=0.006070023148148148
# [yolov5_openvino_fullresol - qp47] BQTerrace_1920x1080_100.yuv: PSNR=26.14, BPP=0.002292476851851852
# [yolov5_openvino_fullresol - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.36, BPP=0.002369483024691358
# [yolov5_openvino_fullresol - qp47] Kimono_1920x1080_100.yuv: PSNR=28.53, BPP=0.003334529320987654
# [yolov5_openvino_fullresol - qp47] Cactus_1920x1080_100.yuv: PSNR=26.64, BPP=0.004009259259259259
# [yolov5_openvino_fullresol - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.73, BPP=0.011905632716049382
# [yolov5_openvino_fullresol - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.48, BPP=0.0039033179012345678
# [yolov5_openvino_fullresol - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.18, BPP=0.004790779320987654
# [yolov5_openvino_fullresol - qp42] Kimono_1920x1080_100.yuv: PSNR=30.83, BPP=0.0067056327160493825
# [yolov5_openvino_fullresol - qp42] Cactus_1920x1080_100.yuv: PSNR=28.82, BPP=0.007943904320987655
# [yolov5_openvino_fullresol - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.40, BPP=0.043338811728395064
# [yolov5_openvino_fullresol - qp32] BQTerrace_1920x1080_100.yuv: PSNR=33.03, BPP=0.027337345679012345
# [yolov5_openvino_fullresol - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.82, BPP=0.024248225308641975
# [yolov5_openvino_fullresol - qp32] Kimono_1920x1080_100.yuv: PSNR=36.23, BPP=0.028200964506172838
# [yolov5_openvino_fullresol - qp32] Cactus_1920x1080_100.yuv: PSNR=33.78, BPP=0.03342986111111111
# [yolov5_openvino_fullresol - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.23, BPP=0.08700131172839506
# [yolov5_openvino_fullresol - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.78, BPP=0.08343337191358025
# [yolov5_openvino_fullresol - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.33, BPP=0.054130632716049384
# [yolov5_openvino_fullresol - qp27] Kimono_1920x1080_100.yuv: PSNR=38.73, BPP=0.05518545524691358
# [yolov5_openvino_fullresol - qp27] Cactus_1920x1080_100.yuv: PSNR=35.93, BPP=0.07220057870370371
# [yolov5_openvino_fullresol - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.88, BPP=0.21220439814814815
# [yolov5_openvino_fullresol - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.64, BPP=0.26507195216049384
# [yolov5_openvino_fullresol - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.86, BPP=0.12182534722222223
# [yolov5_openvino_fullresol - qp22] Kimono_1920x1080_100.yuv: PSNR=40.74, BPP=0.10859008487654322
# [yolov5_openvino_fullresol - qp22] Cactus_1920x1080_100.yuv: PSNR=37.68, BPP=0.18626215277777777
# [yolov5_openvino_fullresol - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.19, BPP=0.022818595679012347
# [yolov5_openvino_fullresol - qp37] BQTerrace_1920x1080_100.yuv: PSNR=31.02, BPP=0.009404436728395062
# [yolov5_openvino_fullresol - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.41, BPP=0.01082962962962963
# [yolov5_openvino_fullresol - qp37] Kimono_1920x1080_100.yuv: PSNR=33.51, BPP=0.013987577160493828
# [yolov5_openvino_fullresol - qp37] Cactus_1920x1080_100.yuv: PSNR=31.37, BPP=0.01637141203703704
# [yolov5 - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.33, BPP=0.006173263888888889
# [yolov5 - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.47, BPP=0.0019617669753086418
# [yolov5 - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.47, BPP=0.002355324074074074
# [yolov5 - qp47] Kimono_1920x1080_100.yuv: PSNR=28.63, BPP=0.0034837577160493826
# [yolov5 - qp47] Cactus_1920x1080_100.yuv: PSNR=26.68, BPP=0.004015663580246914
# [yolov5 - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.76, BPP=0.01196087962962963
# [yolov5 - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.92, BPP=0.003375462962962963
# [yolov5 - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.33, BPP=0.004865007716049382
# [yolov5 - qp42] Kimono_1920x1080_100.yuv: PSNR=30.96, BPP=0.007063503086419753
# [yolov5 - qp42] Cactus_1920x1080_100.yuv: PSNR=28.87, BPP=0.007915239197530864
# [yolov5 - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.40, BPP=0.04331219135802469
# [yolov5 - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.56, BPP=0.020048032407407407
# [yolov5 - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.93, BPP=0.024290470679012344
# [yolov5 - qp32] Kimono_1920x1080_100.yuv: PSNR=36.35, BPP=0.029374112654320987
# [yolov5 - qp32] Cactus_1920x1080_100.yuv: PSNR=33.83, BPP=0.033337075617283954
# [yolov5 - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.23, BPP=0.08683576388888889
# [yolov5 - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.48, BPP=0.06094266975308642
# [yolov5 - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.46, BPP=0.05494054783950617
# [yolov5 - qp27] Kimono_1920x1080_100.yuv: PSNR=38.83, BPP=0.057483989197530866
# [yolov5 - qp27] Cactus_1920x1080_100.yuv: PSNR=36.01, BPP=0.07219710648148148
# [yolov5 - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.87, BPP=0.2120917052469136
# [yolov5 - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.20, BPP=0.19018506944444444
# [yolov5 - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.97, BPP=0.12403302469135802
# [yolov5 - qp22] Kimono_1920x1080_100.yuv: PSNR=40.81, BPP=0.11377488425925926
# [yolov5 - qp22] Cactus_1920x1080_100.yuv: PSNR=37.72, BPP=0.1871488425925926
# [yolov5 - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.19, BPP=0.022823186728395062
# [yolov5 - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.40, BPP=0.007363734567901235
# [yolov5 - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.52, BPP=0.010803163580246914
# [yolov5 - qp37] Kimono_1920x1080_100.yuv: PSNR=33.63, BPP=0.014619598765432099
# [yolov5 - qp37] Cactus_1920x1080_100.yuv: PSNR=31.37, BPP=0.016192708333333333
# [yolov9_old - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.34, BPP=0.0061645833333333335
# [yolov9_old - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.38, BPP=0.0019130401234567901
# [yolov9_old - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.69, BPP=0.0026683256172839506
# [yolov9_old - qp47] Kimono_1920x1080_100.yuv: PSNR=28.63, BPP=0.003489043209876543
# [yolov9_old - qp47] Cactus_1920x1080_100.yuv: PSNR=27.01, BPP=0.004186998456790124
# [yolov9_old - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.72, BPP=0.012009567901234568
# [yolov9_old - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.88, BPP=0.0033415123456790124
# [yolov9_old - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.58, BPP=0.005483873456790123
# [yolov9_old - qp42] Kimono_1920x1080_100.yuv: PSNR=30.96, BPP=0.007084606481481482
# [yolov9_old - qp42] Cactus_1920x1080_100.yuv: PSNR=29.26, BPP=0.008242708333333333
# [yolov9_old - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.40, BPP=0.043431712962962964
# [yolov9_old - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.54, BPP=0.019983796296296295
# [yolov9_old - qp32] ParkScene_1920x1080_100.yuv: PSNR=33.13, BPP=0.026926466049382716
# [yolov9_old - qp32] Kimono_1920x1080_100.yuv: PSNR=36.37, BPP=0.02956886574074074
# [yolov9_old - qp32] Cactus_1920x1080_100.yuv: PSNR=34.08, BPP=0.034244135802469135
# [yolov9_old - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.23, BPP=0.08698908179012346
# [yolov9_old - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.47, BPP=0.06112816358024691
# [yolov9_old - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.61, BPP=0.059998996913580245
# [yolov9_old - qp27] Kimono_1920x1080_100.yuv: PSNR=38.84, BPP=0.057775
# [yolov9_old - qp27] Cactus_1920x1080_100.yuv: PSNR=36.15, BPP=0.07499868827160494
# [yolov9_old - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.87, BPP=0.21238337191358025
# [yolov9_old - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.19, BPP=0.18934313271604938
# [yolov9_old - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.09, BPP=0.13414247685185185
# [yolov9_old - qp22] Kimono_1920x1080_100.yuv: PSNR=40.83, BPP=0.11464776234567901
# [yolov9_old - qp22] Cactus_1920x1080_100.yuv: PSNR=37.81, BPP=0.19728915895061727
# [yolov9_old - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.19, BPP=0.022844907407407408
# [yolov9_old - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.38, BPP=0.007324151234567902
# [yolov9_old - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.75, BPP=0.012109837962962963
# [yolov9_old - qp37] Kimono_1920x1080_100.yuv: PSNR=33.65, BPP=0.014691126543209877
# [yolov9_old - qp37] Cactus_1920x1080_100.yuv: PSNR=31.70, BPP=0.01676400462962963
# [yolov11_openvino_fullresol - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.34, BPP=0.006102893518518519
# [yolov11_openvino_fullresol - qp47] BQTerrace_1920x1080_100.yuv: PSNR=26.20, BPP=0.002289351851851852
# [yolov11_openvino_fullresol - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.45, BPP=0.0023312114197530866
# [yolov11_openvino_fullresol - qp47] Kimono_1920x1080_100.yuv: PSNR=28.51, BPP=0.003320871913580247
# [yolov11_openvino_fullresol - qp47] Cactus_1920x1080_100.yuv: PSNR=26.80, BPP=0.0038765046296296295
# [yolov11_openvino_fullresol - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.72, BPP=0.011892399691358024
# [yolov11_openvino_fullresol - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.59, BPP=0.004021797839506173
# [yolov11_openvino_fullresol - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.32, BPP=0.004755671296296296
# [yolov11_openvino_fullresol - qp42] Kimono_1920x1080_100.yuv: PSNR=30.82, BPP=0.006652469135802469
# [yolov11_openvino_fullresol - qp42] Cactus_1920x1080_100.yuv: PSNR=29.06, BPP=0.007596026234567901
# [yolov11_openvino_fullresol - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.40, BPP=0.043123032407407405
# [yolov11_openvino_fullresol - qp32] BQTerrace_1920x1080_100.yuv: PSNR=33.11, BPP=0.028469020061728394
# [yolov11_openvino_fullresol - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.87, BPP=0.023691435185185187
# [yolov11_openvino_fullresol - qp32] Kimono_1920x1080_100.yuv: PSNR=36.22, BPP=0.027957561728395062
# [yolov11_openvino_fullresol - qp32] Cactus_1920x1080_100.yuv: PSNR=33.91, BPP=0.031824652777777775
# [yolov11_openvino_fullresol - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.24, BPP=0.0865195987654321
# [yolov11_openvino_fullresol - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.85, BPP=0.08709525462962962
# [yolov11_openvino_fullresol - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.40, BPP=0.053427391975308644
# [yolov11_openvino_fullresol - qp27] Kimono_1920x1080_100.yuv: PSNR=38.72, BPP=0.05485335648148148
# [yolov11_openvino_fullresol - qp27] Cactus_1920x1080_100.yuv: PSNR=36.00, BPP=0.06845219907407407
# [yolov11_openvino_fullresol - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.88, BPP=0.2124355324074074
# [yolov11_openvino_fullresol - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.74, BPP=0.2805380401234568
# [yolov11_openvino_fullresol - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.90, BPP=0.12071612654320987
# [yolov11_openvino_fullresol - qp22] Kimono_1920x1080_100.yuv: PSNR=40.73, BPP=0.10862233796296296
# [yolov11_openvino_fullresol - qp22] Cactus_1920x1080_100.yuv: PSNR=37.70, BPP=0.17917646604938273
# [yolov11_openvino_fullresol - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.20, BPP=0.022709143518518517
# [yolov11_openvino_fullresol - qp37] BQTerrace_1920x1080_100.yuv: PSNR=31.02, BPP=0.009604861111111111
# [yolov11_openvino_fullresol - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.47, BPP=0.010589930555555556
# [yolov11_openvino_fullresol - qp37] Kimono_1920x1080_100.yuv: PSNR=33.49, BPP=0.013848225308641975
# [yolov11_openvino_fullresol - qp37] Cactus_1920x1080_100.yuv: PSNR=31.50, BPP=0.015503742283950617
# [yolov8_old - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.38, BPP=0.006162075617283951
# [yolov8_old - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.30, BPP=0.001887577160493827
# [yolov8_old - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.53, BPP=0.00242662037037037
# [yolov8_old - qp47] Kimono_1920x1080_100.yuv: PSNR=28.64, BPP=0.0035142746913580246
# [yolov8_old - qp47] Cactus_1920x1080_100.yuv: PSNR=26.47, BPP=0.0038683256172839507
# [yolov8_old - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.78, BPP=0.012004320987654322
# [yolov8_old - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.80, BPP=0.0032968364197530865
# [yolov8_old - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.41, BPP=0.004983989197530864
# [yolov8_old - qp42] Kimono_1920x1080_100.yuv: PSNR=31.00, BPP=0.007100424382716049
# [yolov8_old - qp42] Cactus_1920x1080_100.yuv: PSNR=28.61, BPP=0.007674884259259259
# [yolov8_old - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.43, BPP=0.04348707561728395
# [yolov8_old - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.55, BPP=0.020310262345679012
# [yolov8_old - qp32] ParkScene_1920x1080_100.yuv: PSNR=33.00, BPP=0.024777006172839507
# [yolov8_old - qp32] Kimono_1920x1080_100.yuv: PSNR=36.38, BPP=0.029662345679012346
# [yolov8_old - qp32] Cactus_1920x1080_100.yuv: PSNR=33.53, BPP=0.032469521604938274
# [yolov8_old - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.25, BPP=0.08725671296296296
# [yolov8_old - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.48, BPP=0.0626323688271605
# [yolov8_old - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.51, BPP=0.055554320987654324
# [yolov8_old - qp27] Kimono_1920x1080_100.yuv: PSNR=38.85, BPP=0.05803148148148148
# [yolov8_old - qp27] Cactus_1920x1080_100.yuv: PSNR=35.75, BPP=0.06981547067901235
# [yolov8_old - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.88, BPP=0.21317299382716048
# [yolov8_old - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.23, BPP=0.1964309413580247
# [yolov8_old - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.01, BPP=0.12559841820987655
# [yolov8_old - qp22] Kimono_1920x1080_100.yuv: PSNR=40.84, BPP=0.11513915895061728
# [yolov8_old - qp22] Cactus_1920x1080_100.yuv: PSNR=37.54, BPP=0.1780306712962963
# [yolov8_old - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.24, BPP=0.022874498456790123
# [yolov8_old - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.37, BPP=0.007443557098765432
# [yolov8_old - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.61, BPP=0.011027391975308642
# [yolov8_old - qp37] Kimono_1920x1080_100.yuv: PSNR=33.67, BPP=0.014751581790123456
# [yolov8_old - qp37] Cactus_1920x1080_100.yuv: PSNR=31.07, BPP=0.015780748456790124
# [yolov11 - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.35, BPP=0.00614471450617284
# [yolov11 - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.61, BPP=0.0020464891975308644
# [yolov11 - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.57, BPP=0.002443942901234568
# [yolov11 - qp47] Kimono_1920x1080_100.yuv: PSNR=28.58, BPP=0.003444212962962963
# [yolov11 - qp47] Cactus_1920x1080_100.yuv: PSNR=26.20, BPP=0.0031471064814814816
# [yolov11 - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.74, BPP=0.011934104938271605
# [yolov11 - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.18, BPP=0.0036784722222222223
# [yolov11 - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.45, BPP=0.005046566358024691
# [yolov11 - qp42] Kimono_1920x1080_100.yuv: PSNR=30.91, BPP=0.006939853395061728
# [yolov11 - qp42] Cactus_1920x1080_100.yuv: PSNR=28.27, BPP=0.005825925925925926
# [yolov11 - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.38, BPP=0.04321057098765432
# [yolov11 - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.76, BPP=0.022695023148148148
# [yolov11 - qp32] ParkScene_1920x1080_100.yuv: PSNR=33.04, BPP=0.025069058641975308
# [yolov11 - qp32] Kimono_1920x1080_100.yuv: PSNR=36.32, BPP=0.028966435185185185
# [yolov11 - qp32] Cactus_1920x1080_100.yuv: PSNR=33.07, BPP=0.02401466049382716
# [yolov11 - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.21, BPP=0.08651678240740741
# [yolov11 - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.61, BPP=0.06919749228395061
# [yolov11 - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.55, BPP=0.05623931327160494
# [yolov11 - qp27] Kimono_1920x1080_100.yuv: PSNR=38.80, BPP=0.05679128086419753
# [yolov11 - qp27] Cactus_1920x1080_100.yuv: PSNR=35.29, BPP=0.05239135802469136
# [yolov11 - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.86, BPP=0.21087283950617283
# [yolov11 - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.37, BPP=0.2191505787037037
# [yolov11 - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.05, BPP=0.12711350308641975
# [yolov11 - qp22] Kimono_1920x1080_100.yuv: PSNR=40.80, BPP=0.11259378858024692
# [yolov11 - qp22] Cactus_1920x1080_100.yuv: PSNR=37.18, BPP=0.1406872299382716
# [yolov11 - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.17, BPP=0.022754128086419752
# ...
# [yolov9_openvino - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.63, BPP=0.0026050154320987656
# [yolov9_openvino - qp47] Kimono_1920x1080_100.yuv: PSNR=28.62, BPP=0.0034816743827160495
# [yolov9_openvino - qp47] Cactus_1920x1080_100.yuv: PSNR=26.94, BPP=0.004114351851851852
# [yolov9_openvino - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.72, BPP=0.01192025462962963
# [yolov9_openvino - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.72, BPP=0.003202932098765432
# [yolov9_openvino - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.54, BPP=0.00536616512345679
# [yolov9_openvino - qp42] Kimono_1920x1080_100.yuv: PSNR=30.96, BPP=0.007066049382716049
# [yolov9_openvino - qp42] Cactus_1920x1080_100.yuv: PSNR=29.18, BPP=0.008079359567901234
# [yolov9_openvino - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.39, BPP=0.04310401234567901
# [yolov9_openvino - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.46, BPP=0.018729243827160492
# [yolov9_openvino - qp32] ParkScene_1920x1080_100.yuv: PSNR=33.08, BPP=0.026427623456790124
# [yolov9_openvino - qp32] Kimono_1920x1080_100.yuv: PSNR=36.36, BPP=0.029449614197530866
# [yolov9_openvino - qp32] Cactus_1920x1080_100.yuv: PSNR=34.03, BPP=0.03359104938271605
# [yolov9_openvino - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.22, BPP=0.08652191358024691
# [yolov9_openvino - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.40, BPP=0.05775281635802469
# [yolov9_openvino - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.58, BPP=0.0589809799382716
# [yolov9_openvino - qp27] Kimono_1920x1080_100.yuv: PSNR=38.84, BPP=0.05775173611111111
# [yolov9_openvino - qp27] Cactus_1920x1080_100.yuv: PSNR=36.12, BPP=0.07344575617283951
# [yolov9_openvino - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.88, BPP=0.2122997299382716
# [yolov9_openvino - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.15, BPP=0.18330185185185185
# [yolov9_openvino - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.06, BPP=0.13287935956790123
# [yolov9_openvino - qp22] Kimono_1920x1080_100.yuv: PSNR=40.83, BPP=0.11481489197530864
# [yolov9_openvino - qp22] Cactus_1920x1080_100.yuv: PSNR=37.80, BPP=0.19459733796296297
# [yolov9_openvino - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.17, BPP=0.02273912037037037
# [yolov9_openvino - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.22, BPP=0.006931983024691358
# [yolov9_openvino - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.69, BPP=0.011811226851851852
# [yolov9_openvino - qp37] Kimono_1920x1080_100.yuv: PSNR=33.65, BPP=0.014649382716049382
# [yolov9_openvino - qp37] Cactus_1920x1080_100.yuv: PSNR=31.64, BPP=0.01647434413580247
# [nonroi_CQP - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=29.55, BPP=0.006504822530864198
# [nonroi_CQP - qp47] BQTerrace_1920x1080_100.yuv: PSNR=26.75, BPP=0.002133256172839506
# [nonroi_CQP - qp47] ParkScene_1920x1080_100.yuv: PSNR=27.41, BPP=0.003166743827160494
# [nonroi_CQP - qp47] Kimono_1920x1080_100.yuv: PSNR=30.37, BPP=0.00475108024691358
# [nonroi_CQP - qp47] Cactus_1920x1080_100.yuv: PSNR=27.60, BPP=0.004516782407407408
# [nonroi_CQP - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=32.05, BPP=0.013029976851851852
# [nonroi_CQP - qp42] BQTerrace_1920x1080_100.yuv: PSNR=29.33, BPP=0.004295563271604939
# [nonroi_CQP - qp42] ParkScene_1920x1080_100.yuv: PSNR=29.52, BPP=0.007222569444444445
# [nonroi_CQP - qp42] Kimono_1920x1080_100.yuv: PSNR=33.17, BPP=0.010654783950617284
# [nonroi_CQP - qp42] Cactus_1920x1080_100.yuv: PSNR=30.07, BPP=0.009520949074074074
# [nonroi_CQP - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=36.40, BPP=0.049274652777777775
# [nonroi_CQP - qp32] BQTerrace_1920x1080_100.yuv: PSNR=33.65, BPP=0.03019008487654321
# [nonroi_CQP - qp32] ParkScene_1920x1080_100.yuv: PSNR=34.54, BPP=0.04107550154320987
# [nonroi_CQP - qp32] Kimono_1920x1080_100.yuv: PSNR=38.51, BPP=0.045155092592592594
# [nonroi_CQP - qp32] Cactus_1920x1080_100.yuv: PSNR=34.91, BPP=0.04208348765432099
# [nonroi_CQP - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=38.04, BPP=0.10250779320987655
# [nonroi_CQP - qp27] BQTerrace_1920x1080_100.yuv: PSNR=35.87, BPP=0.12406805555555556
# [nonroi_CQP - qp27] ParkScene_1920x1080_100.yuv: PSNR=37.25, BPP=0.09769263117283951
# [nonroi_CQP - qp27] Kimono_1920x1080_100.yuv: PSNR=40.58, BPP=0.08617492283950617
# [nonroi_CQP - qp27] Cactus_1920x1080_100.yuv: PSNR=36.84, BPP=0.09562465277777778
# [nonroi_CQP - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=39.70, BPP=0.28517430555555556
# [nonroi_CQP - qp22] BQTerrace_1920x1080_100.yuv: PSNR=38.95, BPP=0.5289359567901235
# [nonroi_CQP - qp22] ParkScene_1920x1080_100.yuv: PSNR=39.93, BPP=0.23801087962962963
# [nonroi_CQP - qp22] Kimono_1920x1080_100.yuv: PSNR=42.09, BPP=0.17341913580246915
# [nonroi_CQP - qp22] Cactus_1920x1080_100.yuv: PSNR=38.85, BPP=0.34165447530864196
# [nonroi_CQP - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=34.39, BPP=0.025360956790123457
# [nonroi_CQP - qp37] BQTerrace_1920x1080_100.yuv: PSNR=31.53, BPP=0.010245987654320988
# [nonroi_CQP - qp37] ParkScene_1920x1080_100.yuv: PSNR=31.93, BPP=0.017190200617283952
# [nonroi_CQP - qp37] Kimono_1920x1080_100.yuv: PSNR=35.98, BPP=0.022662345679012347
# [nonroi_CQP - qp37] Cactus_1920x1080_100.yuv: PSNR=32.59, BPP=0.019925347222222223
# [yolov11_openvino - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.29, BPP=0.006091512345679013
# [yolov11_openvino - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.47, BPP=0.0019589120370370372
# [yolov11_openvino - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.49, BPP=0.002398611111111111
# [yolov11_openvino - qp47] Kimono_1920x1080_100.yuv: PSNR=28.59, BPP=0.00341141975308642
# [yolov11_openvino - qp47] Cactus_1920x1080_100.yuv: PSNR=26.13, BPP=0.0030928240740740742
# [yolov11_openvino - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.71, BPP=0.011848032407407408
# [yolov11_openvino - qp42] BQTerrace_1920x1080_100.yuv: PSNR=27.98, BPP=0.0034875385802469135
# [yolov11_openvino - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.40, BPP=0.004906134259259259
# [yolov11_openvino - qp42] Kimono_1920x1080_100.yuv: PSNR=30.92, BPP=0.006881712962962963
# [yolov11_openvino - qp42] Cactus_1920x1080_100.yuv: PSNR=28.19, BPP=0.005699691358024691
# [yolov11_openvino - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.38, BPP=0.04287534722222222
# [yolov11_openvino - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.67, BPP=0.021257484567901233
# [yolov11_openvino - qp32] ParkScene_1920x1080_100.yuv: PSNR=33.00, BPP=0.024566898148148147
# [yolov11_openvino - qp32] Kimono_1920x1080_100.yuv: PSNR=36.32, BPP=0.02896350308641975
# [yolov11_openvino - qp32] Cactus_1920x1080_100.yuv: PSNR=33.01, BPP=0.02360775462962963
# [yolov11_openvino - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.20, BPP=0.08601639660493827
# [yolov11_openvino - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.54, BPP=0.0657025462962963
# [yolov11_openvino - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.51, BPP=0.05531956018518518
# [yolov11_openvino - qp27] Kimono_1920x1080_100.yuv: PSNR=38.80, BPP=0.05677218364197531
# [yolov11_openvino - qp27] Cactus_1920x1080_100.yuv: PSNR=35.25, BPP=0.05128780864197531
# [yolov11_openvino - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.86, BPP=0.21050644290123458
# [yolov11_openvino - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.33, BPP=0.2133815586419753
# [yolov11_openvino - qp22] ParkScene_1920x1080_100.yuv: PSNR=38.02, BPP=0.12566585648148149
# [yolov11_openvino - qp22] Kimono_1920x1080_100.yuv: PSNR=40.80, BPP=0.11279448302469136
# [yolov11_openvino - qp22] Cactus_1920x1080_100.yuv: PSNR=37.16, BPP=0.13846141975308643
# [yolov11_openvino - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.16, BPP=0.02259008487654321
# [yolov11_openvino - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.53, BPP=0.007854166666666667
# [yolov11_openvino - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.60, BPP=0.010917129629629629
# [yolov11_openvino - qp37] Kimono_1920x1080_100.yuv: PSNR=33.60, BPP=0.014368518518518518
# [yolov11_openvino - qp37] Cactus_1920x1080_100.yuv: PSNR=30.57, BPP=0.011608757716049382
# [nonroi_CRF - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.20, BPP=0.0047290895061728394
# [nonroi_CRF - qp47] BQTerrace_1920x1080_100.yuv: PSNR=26.27, BPP=0.0020743055555555554
# [nonroi_CRF - qp47] ParkScene_1920x1080_100.yuv: PSNR=27.21, BPP=0.002887615740740741
# [nonroi_CRF - qp47] Kimono_1920x1080_100.yuv: PSNR=29.07, BPP=0.0033915123456790125
# [nonroi_CRF - qp47] Cactus_1920x1080_100.yuv: PSNR=27.00, BPP=0.0038690586419753087
# [nonroi_CRF - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.64, BPP=0.008586574074074075
# [nonroi_CRF - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.89, BPP=0.003908950617283951
# [nonroi_CRF - qp42] ParkScene_1920x1080_100.yuv: PSNR=29.25, BPP=0.006265162037037037
# [nonroi_CRF - qp42] Kimono_1920x1080_100.yuv: PSNR=31.60, BPP=0.0070425925925925925
# [nonroi_CRF - qp42] Cactus_1920x1080_100.yuv: PSNR=29.29, BPP=0.0075863425925925924
# [nonroi_CRF - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.30, BPP=0.03228032407407407
# [nonroi_CRF - qp32] BQTerrace_1920x1080_100.yuv: PSNR=33.43, BPP=0.0270875
# [nonroi_CRF - qp32] ParkScene_1920x1080_100.yuv: PSNR=34.10, BPP=0.033071141975308645
# [nonroi_CRF - qp32] Kimono_1920x1080_100.yuv: PSNR=37.05, BPP=0.030078395061728394
# [nonroi_CRF - qp32] Cactus_1920x1080_100.yuv: PSNR=34.14, BPP=0.03146427469135803
# [nonroi_CRF - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.14, BPP=0.06352542438271605
# [nonroi_CRF - qp27] BQTerrace_1920x1080_100.yuv: PSNR=35.22, BPP=0.08773055555555556
# [nonroi_CRF - qp27] ParkScene_1920x1080_100.yuv: PSNR=36.65, BPP=0.07525717592592593
# [nonroi_CRF - qp27] Kimono_1920x1080_100.yuv: PSNR=39.37, BPP=0.0583022762345679
# [nonroi_CRF - qp27] Cactus_1920x1080_100.yuv: PSNR=36.19, BPP=0.0683460262345679
# [nonroi_CRF - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.61, BPP=0.14318337191358024
# [nonroi_CRF - qp22] BQTerrace_1920x1080_100.yuv: PSNR=37.09, BPP=0.2677883101851852
# [nonroi_CRF - qp22] ParkScene_1920x1080_100.yuv: PSNR=39.10, BPP=0.17251118827160494
# [nonroi_CRF - qp22] Kimono_1920x1080_100.yuv: PSNR=41.18, BPP=0.11295165895061729
# [nonroi_CRF - qp22] Cactus_1920x1080_100.yuv: PSNR=37.85, BPP=0.18037804783950617
# [nonroi_CRF - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.10, BPP=0.01683827160493827
# [nonroi_CRF - qp37] BQTerrace_1920x1080_100.yuv: PSNR=31.27, BPP=0.009148649691358025
# [nonroi_CRF - qp37] ParkScene_1920x1080_100.yuv: PSNR=31.59, BPP=0.014335416666666666
# [nonroi_CRF - qp37] Kimono_1920x1080_100.yuv: PSNR=34.38, BPP=0.01487716049382716
# [nonroi_CRF - qp37] Cactus_1920x1080_100.yuv: PSNR=31.76, BPP=0.015466358024691358
# [yolov8_openvino_fullresol - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=28.36, BPP=0.0061264274691358025
# [yolov8_openvino_fullresol - qp47] BQTerrace_1920x1080_100.yuv: PSNR=26.23, BPP=0.0023566743827160494
# [yolov8_openvino_fullresol - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.26, BPP=0.002230671296296296
# [yolov8_openvino_fullresol - qp47] Kimono_1920x1080_100.yuv: PSNR=28.60, BPP=0.0034181712962962963
# [yolov8_openvino_fullresol - qp47] Cactus_1920x1080_100.yuv: PSNR=26.43, BPP=0.003773070987654321
# [yolov8_openvino_fullresol - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.77, BPP=0.011920370370370371
# [yolov8_openvino_fullresol - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.65, BPP=0.004132793209876543
# [yolov8_openvino_fullresol - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.11, BPP=0.004551967592592593
# [yolov8_openvino_fullresol - qp42] Kimono_1920x1080_100.yuv: PSNR=30.93, BPP=0.006934375
# [yolov8_openvino_fullresol - qp42] Cactus_1920x1080_100.yuv: PSNR=28.55, BPP=0.007336458333333334
# [yolov8_openvino_fullresol - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=35.44, BPP=0.04340976080246914
# [yolov8_openvino_fullresol - qp32] BQTerrace_1920x1080_100.yuv: PSNR=33.14, BPP=0.03017013888888889
# [yolov8_openvino_fullresol - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.68, BPP=0.022636265432098766
# [yolov8_openvino_fullresol - qp32] Kimono_1920x1080_100.yuv: PSNR=36.33, BPP=0.029092438271604938
# [yolov8_openvino_fullresol - qp32] Cactus_1920x1080_100.yuv: PSNR=33.41, BPP=0.030569675925925927
# [yolov8_openvino_fullresol - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=37.26, BPP=0.08708314043209876
# [yolov8_openvino_fullresol - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.90, BPP=0.0927945987654321
# [yolov8_openvino_fullresol - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.22, BPP=0.05122908950617284
# [yolov8_openvino_fullresol - qp27] Kimono_1920x1080_100.yuv: PSNR=38.81, BPP=0.05691936728395062
# [yolov8_openvino_fullresol - qp27] Cactus_1920x1080_100.yuv: PSNR=35.59, BPP=0.06528402777777778
# [yolov8_openvino_fullresol - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.90, BPP=0.21404918981481483
# [yolov8_openvino_fullresol - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.84, BPP=0.2993945216049383
# [yolov8_openvino_fullresol - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.77, BPP=0.11572511574074074
# [yolov8_openvino_fullresol - qp22] Kimono_1920x1080_100.yuv: PSNR=40.80, BPP=0.11227168209876544
# [yolov8_openvino_fullresol - qp22] Cactus_1920x1080_100.yuv: PSNR=37.43, BPP=0.16939537037037036
# [yolov8_openvino_fullresol - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=33.23, BPP=0.02275439814814815
# [yolov8_openvino_fullresol - qp37] BQTerrace_1920x1080_100.yuv: PSNR=31.05, BPP=0.009827083333333334
# [yolov8_openvino_fullresol - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.26, BPP=0.010062924382716049
# [yolov8_openvino_fullresol - qp37] Kimono_1920x1080_100.yuv: PSNR=33.61, BPP=0.014468479938271606
# [yolov8_openvino_fullresol - qp37] Cactus_1920x1080_100.yuv: PSNR=30.98, BPP=0.014918788580246914
# [motion - qp47] BasketballDrive_1920x1080_100.yuv: PSNR=27.87, BPP=0.005406134259259259
# [motion - qp47] BQTerrace_1920x1080_100.yuv: PSNR=25.97, BPP=0.002049614197530864
# [motion - qp47] ParkScene_1920x1080_100.yuv: PSNR=26.48, BPP=0.002373649691358025
# [motion - qp47] Kimono_1920x1080_100.yuv: PSNR=28.08, BPP=0.0027630015432098766
# [motion - qp47] Cactus_1920x1080_100.yuv: PSNR=26.23, BPP=0.003144791666666667
# [motion - qp42] BasketballDrive_1920x1080_100.yuv: PSNR=30.09, BPP=0.01024483024691358
# [motion - qp42] BQTerrace_1920x1080_100.yuv: PSNR=28.42, BPP=0.0036427469135802467
# [motion - qp42] ParkScene_1920x1080_100.yuv: PSNR=28.34, BPP=0.004844598765432099
# [motion - qp42] Kimono_1920x1080_100.yuv: PSNR=30.34, BPP=0.005358912037037037
# [motion - qp42] Cactus_1920x1080_100.yuv: PSNR=28.26, BPP=0.005795331790123457
# [motion - qp32] BasketballDrive_1920x1080_100.yuv: PSNR=34.84, BPP=0.036281867283950615
# [motion - qp32] BQTerrace_1920x1080_100.yuv: PSNR=32.74, BPP=0.020609799382716048
# [motion - qp32] ParkScene_1920x1080_100.yuv: PSNR=32.89, BPP=0.024107021604938272
# [motion - qp32] Kimono_1920x1080_100.yuv: PSNR=35.71, BPP=0.02243383487654321
# [motion - qp32] Cactus_1920x1080_100.yuv: PSNR=33.02, BPP=0.023205902777777777
# [motion - qp27] BasketballDrive_1920x1080_100.yuv: PSNR=36.76, BPP=0.07098248456790124
# [motion - qp27] BQTerrace_1920x1080_100.yuv: PSNR=34.57, BPP=0.06261666666666667
# [motion - qp27] ParkScene_1920x1080_100.yuv: PSNR=35.38, BPP=0.05374502314814815
# [motion - qp27] Kimono_1920x1080_100.yuv: PSNR=38.25, BPP=0.04412218364197531
# [motion - qp27] Cactus_1920x1080_100.yuv: PSNR=35.20, BPP=0.04740019290123457
# [motion - qp22] BasketballDrive_1920x1080_100.yuv: PSNR=38.41, BPP=0.16495007716049384
# [motion - qp22] BQTerrace_1920x1080_100.yuv: PSNR=36.28, BPP=0.19075497685185186
# [motion - qp22] ParkScene_1920x1080_100.yuv: PSNR=37.87, BPP=0.11976057098765432
# [motion - qp22] Kimono_1920x1080_100.yuv: PSNR=40.33, BPP=0.08472951388888889
# [motion - qp22] Cactus_1920x1080_100.yuv: PSNR=37.01, BPP=0.11222465277777778
# [motion - qp37] BasketballDrive_1920x1080_100.yuv: PSNR=32.57, BPP=0.01934212962962963
# [motion - qp37] BQTerrace_1920x1080_100.yuv: PSNR=30.73, BPP=0.007838811728395062
# [motion - qp37] ParkScene_1920x1080_100.yuv: PSNR=30.51, BPP=0.010814621913580246
# [motion - qp37] Kimono_1920x1080_100.yuv: PSNR=32.97, BPP=0.011083179012345679
# [motion - qp37] Cactus_1920x1080_100.yuv: PSNR=30.63, BPP=0.011569868827160493
# --> Đang xuất Excel: report_psnr_bpp.xlsx
# --> Hoàn tất!

# %% [markdown]
# # 4. BD-rate

# %%
import pandas as pd
import numpy as np
import scipy.interpolate
import os

# --- CẤU HÌNH ---
ROOT_DIR = 'logs_RCF'
INPUT_FILE = os.path.join(ROOT_DIR, 'report_psnr_bpp.xlsx')

# Tên Method dùng làm mốc so sánh (Reference)
# Hãy đổi tên này trùng khớp với tên trong cột Method của file Excel
ANCHOR_METHOD = 'nonroi_CQP' 

def bd_rate(rate_anchor, psnr_anchor, rate_test, psnr_test):
    """
    Tính BD-Rate theo thuật toán VCEG-M33 (Bjøntegaard).
    Input:
        rate_anchor, psnr_anchor: List/Array BPP và PSNR của Anchor
        rate_test, psnr_test: List/Array BPP và PSNR của Test Method
    Output:
        Giá trị % thay đổi bitrate (BD-Rate).
    """
    
    # Chuyển sang numpy array và logarit cơ số 10 cho Rate
    ra = np.log10(rate_anchor)
    rt = np.log10(rate_test)
    pa = np.array(psnr_anchor)
    pt = np.array(psnr_test)

    # Tìm khoảng PSNR chung (Overlap range) để tích phân
    min_psnr = max(np.min(pa), np.min(pt))
    max_psnr = min(np.max(pa), np.max(pt))

    # Nếu không có khoảng chung hợp lệ
    if min_psnr >= max_psnr:
        return np.nan

    # Fit đa thức bậc 3: Log-Rate theo PSNR
    # p_anchor(x) = a + bx + cx^2 + dx^3
    p_anchor = np.polyfit(pa, ra, 3)
    p_test = np.polyfit(pt, rt, 3)

    # Tạo hàm đa thức từ hệ số
    poly_anchor = np.poly1d(p_anchor)
    poly_test = np.poly1d(p_test)

    # Tính tích phân xác định trong khoảng [min_psnr, max_psnr]
    # Hàm integ() của numpy trả về nguyên hàm, ta thay cận vào
    int_anchor = poly_anchor.integ()(max_psnr) - poly_anchor.integ()(min_psnr)
    int_test = poly_test.integ()(max_psnr) - poly_test.integ()(min_psnr)

    # Tính trung bình hiệu số log-rate
    avg_diff = (int_test - int_anchor) / (max_psnr - min_psnr)

    # Chuyển từ log space về phần trăm
    bd_rate_val = (np.power(10, avg_diff) - 1) * 100
    
    return bd_rate_val

def calculate_bd_rate_report():
    print(f"--> Đang đọc dữ liệu từ: {INPUT_FILE}")
    
    # 1. Đọc dữ liệu từ Excel
    try:
        df_psnr = pd.read_excel(INPUT_FILE, sheet_name='Average PSNR (dB)', index_col='Method')
        df_bpp = pd.read_excel(INPUT_FILE, sheet_name='Average BPP', index_col='Method')
    except Exception as e:
        print(f"Lỗi đọc file: {e}")
        return

    # 2. Lọc bỏ cột 'Average' nếu có, chỉ giữ lại các cột QP (qpXX)
    qp_cols = [c for c in df_psnr.columns if c != 'Average']
    
    # Kiểm tra xem Anchor có tồn tại không
    if ANCHOR_METHOD not in df_psnr.index:
        print(f"LỖI: Không tìm thấy method '{ANCHOR_METHOD}' trong file Excel để làm Anchor.")
        print(f"Các method hiện có: {list(df_psnr.index)}")
        return

    # Lấy dữ liệu của Anchor
    anchor_psnr = df_psnr.loc[ANCHOR_METHOD, qp_cols].values
    anchor_bpp = df_bpp.loc[ANCHOR_METHOD, qp_cols].values

    # Loại bỏ các giá trị NaN của Anchor (nếu có QP bị thiếu)
    valid_mask_a = ~np.isnan(anchor_psnr) & ~np.isnan(anchor_bpp)
    anchor_psnr = anchor_psnr[valid_mask_a]
    anchor_bpp = anchor_bpp[valid_mask_a]

    if len(anchor_psnr) < 4:
        print("Cảnh báo: Anchor có ít hơn 4 điểm dữ liệu (QP), kết quả BD-Rate có thể không chính xác.")

    results = []

    print(f"--> Đang tính toán BD-Rate (Anchor: {ANCHOR_METHOD})...")

    # 3. Duyệt qua từng method để tính BD-Rate
    for method in df_psnr.index:
        if method == ANCHOR_METHOD:
            results.append({'Method': method, 'BD-Rate (%)': 0.0})
            continue

        # Lấy dữ liệu Test Method
        test_psnr = df_psnr.loc[method, qp_cols].values
        test_bpp = df_bpp.loc[method, qp_cols].values

        # Lọc NaN
        valid_mask_t = ~np.isnan(test_psnr) & ~np.isnan(test_bpp)
        test_psnr = test_psnr[valid_mask_t]
        test_bpp = test_bpp[valid_mask_t]

        # Yêu cầu tối thiểu 4 điểm để fit curve bậc 3
        if len(test_psnr) < 4:
            print(f"Skip {method}: Không đủ 4 điểm dữ liệu.")
            results.append({'Method': method, 'BD-Rate (%)': 'N/A'})
            continue

        try:
            val = bd_rate(anchor_bpp, anchor_psnr, test_bpp, test_psnr)
            results.append({'Method': method, 'BD-Rate (%)': val})
        except Exception as e:
            print(f"Lỗi tính toán {method}: {e}")
            results.append({'Method': method, 'BD-Rate (%)': 'Error'})

    # 4. Lưu kết quả
    df_result = pd.DataFrame(results)
    
    # Format số đẹp (làm tròn 2 chữ số)
    # Lưu vào Sheet mới trong file cũ
    with pd.ExcelWriter(INPUT_FILE, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        df_result.to_excel(writer, sheet_name='BD-Rate Analysis', index=False)

    print(f"--> Hoàn tất! Đã thêm sheet 'BD-Rate Analysis' vào file {INPUT_FILE}")

if __name__ == "__main__":
    calculate_bd_rate_report()
# Out:
# --> Đang đọc dữ liệu từ: logs_RCF/report_psnr_bpp.xlsx
# --> Đang tính toán BD-Rate (Anchor: nonroi_CQP)...
# --> Hoàn tất! Đã thêm sheet 'BD-Rate Analysis' vào file logs_RCF/report_psnr_bpp.xlsx

# %%
import pandas as pd
import numpy as np
import scipy.interpolate
import os

# --- CẤU HÌNH ---
ROOT_DIR = 'logs_RCF'
INPUT_FILE = os.path.join(ROOT_DIR, 'report_psnr_bpp.xlsx')

# DANH SÁCH CÁC ANCHOR MUỐN SO SÁNH
# Lưu ý: Tên trong list này phải KHỚP CHÍNH XÁC (từng ký tự) với cột Method trong file Excel
ANCHOR_LIST = ['nonroi_CQP', 'nonroi_CRF'] 
# Nếu file của bạn tên là 'nonroi_CRF' thì sửa dòng trên thành: ['nonroi_CQP', 'nonroi_CRF']

def bd_rate(rate_anchor, psnr_anchor, rate_test, psnr_test):
    """
    Tính BD-Rate theo thuật toán VCEG-M33.
    """
    ra = np.log10(rate_anchor)
    rt = np.log10(rate_test)
    pa = np.array(psnr_anchor)
    pt = np.array(psnr_test)

    min_psnr = max(np.min(pa), np.min(pt))
    max_psnr = min(np.max(pa), np.max(pt))

    if min_psnr >= max_psnr:
        return np.nan

    try:
        # Fit đa thức bậc 3
        p_anchor = np.polyfit(pa, ra, 3)
        p_test = np.polyfit(pt, rt, 3)

        poly_anchor = np.poly1d(p_anchor)
        poly_test = np.poly1d(p_test)

        # Tích phân
        int_anchor = poly_anchor.integ()(max_psnr) - poly_anchor.integ()(min_psnr)
        int_test = poly_test.integ()(max_psnr) - poly_test.integ()(min_psnr)

        avg_diff = (int_test - int_anchor) / (max_psnr - min_psnr)
        bd_rate_val = (np.power(10, avg_diff) - 1) * 100
        return bd_rate_val
    except Exception:
        return np.nan

def calculate_bd_rate_report():
    print(f"--> Đang đọc dữ liệu từ: {INPUT_FILE}")
    
    try:
        df_psnr = pd.read_excel(INPUT_FILE, sheet_name='Average PSNR (dB)', index_col='Method')
        df_bpp = pd.read_excel(INPUT_FILE, sheet_name='Average BPP', index_col='Method')
    except Exception as e:
        print(f"Lỗi đọc file: {e}")
        return

    # Lọc lấy các cột QP (loại bỏ cột Average nếu có)
    qp_cols = [c for c in df_psnr.columns if str(c).lower() != 'average']
    
    # 1. CHUẨN BỊ DỮ LIỆU CỦA CÁC ANCHOR
    anchors_data = {}
    
    print(f"--> Đang tải dữ liệu Anchor: {ANCHOR_LIST}...")
    for anchor_name in ANCHOR_LIST:
        if anchor_name not in df_psnr.index:
            print(f"[CẢNH BÁO] Không tìm thấy method '{anchor_name}' trong file Excel. Bỏ qua.")
            anchors_data[anchor_name] = None
            continue
            
        a_psnr = df_psnr.loc[anchor_name, qp_cols].values
        a_bpp = df_bpp.loc[anchor_name, qp_cols].values
        
        # Lọc NaN
        mask = ~np.isnan(a_psnr) & ~np.isnan(a_bpp)
        anchors_data[anchor_name] = {
            'psnr': a_psnr[mask],
            'bpp': a_bpp[mask]
        }

    results = []

    # 2. TÍNH TOÁN CHO TỪNG METHOD
    print(f"--> Đang tính toán BD-Rate...")
    
    for method in df_psnr.index:
        # Tạo dictionary chứa kết quả cho dòng hiện tại
        row_result = {'Method': method}
        
        # Lấy dữ liệu Test
        t_psnr = df_psnr.loc[method, qp_cols].values
        t_bpp = df_bpp.loc[method, qp_cols].values
        mask_t = ~np.isnan(t_psnr) & ~np.isnan(t_bpp)
        t_psnr_clean = t_psnr[mask_t]
        t_bpp_clean = t_bpp[mask_t]

        # Duyệt qua từng Anchor để tính BD-Rate riêng biệt
        for anchor_name in ANCHOR_LIST:
            col_name = f'BD-Rate vs {anchor_name} (%)'
            
            # Nếu method hiện tại chính là anchor -> BD-Rate = 0
            if method == anchor_name:
                row_result[col_name] = 0.0
                continue
                
            # Nếu dữ liệu Anchor lỗi hoặc Test không đủ điểm
            if anchors_data.get(anchor_name) is None or len(t_psnr_clean) < 4:
                row_result[col_name] = 'N/A'
                continue

            # Lấy dữ liệu Anchor đã chuẩn bị
            a_psnr_clean = anchors_data[anchor_name]['psnr']
            a_bpp_clean = anchors_data[anchor_name]['bpp']
            
            if len(a_psnr_clean) < 4:
                row_result[col_name] = 'Anchor N/A'
                continue

            # Tính toán
            val = bd_rate(a_bpp_clean, a_psnr_clean, t_bpp_clean, t_psnr_clean)
            
            if np.isnan(val):
                row_result[col_name] = 'Range Error' # Không có khoảng overlap PSNR
            else:
                row_result[col_name] = val

        results.append(row_result)

    # 3. LƯU KẾT QUẢ
    df_result = pd.DataFrame(results)
    
    # Format lại index cho đẹp (cho cột Method ra đầu tiên)
    cols = ['Method'] + [f'BD-Rate vs {a} (%)' for a in ANCHOR_LIST if a in anchors_data]
    # Lọc lại phòng trường hợp có cột thừa do lỗi
    existing_cols = [c for c in cols if c in df_result.columns]
    df_result = df_result[existing_cols]

    with pd.ExcelWriter(INPUT_FILE, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        df_result.to_excel(writer, sheet_name='BD-Rate Comparison', index=False)

    print(f"--> Hoàn tất! Đã lưu sheet 'BD-Rate Comparison' vào file {INPUT_FILE}")
    print(f"--> Các cột được tạo: {[c for c in df_result.columns if c != 'Method']}")

if __name__ == "__main__":
    calculate_bd_rate_report()
# Out:
# --> Đang đọc dữ liệu từ: logs_RCF/report_psnr_bpp.xlsx
# --> Đang tải dữ liệu Anchor: ['nonroi_CQP', 'nonroi_CRF']...
# --> Đang tính toán BD-Rate...
# --> Hoàn tất! Đã lưu sheet 'BD-Rate Comparison' vào file logs_RCF/report_psnr_bpp.xlsx
# --> Các cột được tạo: ['BD-Rate vs nonroi_CQP (%)', 'BD-Rate vs nonroi_CRF (%)']

# %% [markdown]
# # 5. Draw vmaf

# %%
import os
import json
import numpy as np
import math

VMAF_ROOT = "./vmaf_results"
QPS = [22, 27, 32, 37, 42, 47]

def read_vmaf_mean(json_path):
    with open(json_path, "r") as f:
        data = json.load(f)
    return data["pooled_metrics"]["vmaf"]["mean"]

table = {}

for method in sorted(os.listdir(VMAF_ROOT)):
    method_path = os.path.join(VMAF_ROOT, method)
    if not os.path.isdir(method_path):
        continue

    qp_values = {qp: [] for qp in QPS}

    for seq in os.listdir(method_path):
        seq_path = os.path.join(method_path, seq)
        if not os.path.isdir(seq_path):
            continue

        for qp in QPS:
            json_file = os.path.join(seq_path, f"vmaf_qp{qp}.json")
            if os.path.exists(json_file):
                qp_values[qp].append(read_vmaf_mean(json_file))

    qp_means = {}
    valid_qps = []

    for qp in QPS:
        if len(qp_values[qp]) > 0:
            mean_val = float(np.mean(qp_values[qp]))
            qp_means[qp] = mean_val
            valid_qps.append(mean_val)
        else:
            qp_means[qp] = None

    avg_vmaf = np.mean(valid_qps) if valid_qps else None
    table[method] = (qp_means, avg_vmaf)

# ===============================
# PRINT TABLE (SAFE FORMAT)
# ===============================
header = f"{'Method':22} " + " ".join([f"qp{qp:>4}" for qp in QPS]) + "  Average"
print(header)
print("-" * len(header))

for method, (qp_means, avg) in table.items():
    row = f"{method:22} "
    for qp in QPS:
        v = qp_means[qp]
        row += f"{v:6.2f} " if v is not None and not math.isnan(v) else "  --   "
    row += f"{avg:8.2f}" if avg is not None else "   --"
    print(row)
# Out:
# Method                 qp  22 qp  27 qp  32 qp  37 qp  42 qp  47  Average
# -------------------------------------------------------------------------
# motion                  94.82  87.85  76.18  60.69  43.83  29.28    65.44
# motion_old              94.82  87.85  76.18  60.69  43.83  29.28    65.44
# nonroi                  97.97  94.10  85.84  72.66  55.58  38.37    74.09
# nonroi_CQP              98.42  94.76  86.48  72.74  54.93  36.81    74.02
# nonroi_CQP_old          98.42  94.76  86.48  72.74  54.93  36.81    74.02
# nonroi_CRF              95.98  90.58  80.89  66.31  48.61  32.44    69.14
# nonroi_CRF_old          96.76  91.45  81.53  66.68  48.88  32.68    69.66
# saliency                95.14  88.10  76.12  59.68  41.95  26.65    64.61
# saliency_old            95.14  88.10  76.12  59.68  41.95  26.65    64.61
# temp.hevc                --     --     --     --     --     --      --
# yolov11                 95.63  89.44  78.44  63.20  46.14  31.33    67.36
# yolov11_fullresol       95.81  89.87  79.25  64.43  47.42  32.49    68.21
# yolov11_old             95.63  89.44  78.44  63.20  46.14  31.33    67.36
# yolov11_openvino        95.61  89.33  78.24  62.83  45.54  30.64    67.03
# yolov11_openvino_fullresol  95.81  89.87  79.29  64.44  47.52  32.43    68.23
# yolov5                  95.86  89.91  79.08  63.69  46.31  31.17    67.67
# yolov5_fullresol        95.82  89.78  79.05  64.02  47.05  31.49    67.87
# yolov5_old              95.86  89.91  79.08  63.69  46.31  31.17    67.67
# yolov5_openvino         95.87  89.89  79.06  63.73  42.88  30.53    66.99
# yolov5_openvino_fullresol  95.82  89.76  79.04  63.98  46.40  31.44    67.74
# yolov8                  95.80  89.77  78.84  63.37  45.79  30.47    67.34
# yolov8_fullresol        95.72  89.55  78.73  63.43  46.54  31.57    67.59
# yolov8_old              95.80  89.77  78.84  63.37  45.79  30.47    67.34
# yolov8_openvino         95.77  89.67  78.62  62.96  45.37  30.01    67.07
# yolov8_openvino_fullresol  95.73  89.59  78.75  63.42  46.47  31.36    67.55
# yolov9                  95.96  90.12  79.54  64.59  47.52  32.06    68.30
# yolov9_fullresol        95.94  90.01  79.31  64.26  47.07  31.64    68.04
# yolov9_old              95.96  90.12  79.54  64.59  47.52  32.06    68.30
# yolov9_openvino         95.93  90.04  79.35  64.20  46.87  31.15    67.92
# yolov9_openvino_fullresol  95.93  89.99  79.34  64.22  47.10  31.80    68.06
